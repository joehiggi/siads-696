# %% [markdown]
# #

# %% [markdown]
# # Supervised Learning

# %% [markdown]
# By Spencer Cheung, Phuc Nguyen, Joey Higgins

# %% [markdown]
# ### TODO

# %% [markdown]
# - Price

# %%
# use XGBoost
# IMF Exchange Rates, Yahoo FX (yfinance)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.stattools import grangercausalitytests
from xgboost import XGBRegressor, XGBClassifier
from sklearn.metrics import mean_squared_error, confusion_matrix, mean_absolute_error
from sklearn.model_selection import TimeSeriesSplit, RandomizedSearchCV
from sklearn.model_selection import train_test_split

# %%
lreturn = pd.read_parquet('/work/fx_log_return.parquet')
lreturn
# Out:
#            CNY       EUR       JPY       CAD       BRL       MXN       COP  \
# 0     0.007527  0.007623  0.001206  0.005128  0.006958  0.007574  0.007806
# 1     0.004706 -0.000502 -0.003755 -0.000802 -0.001379  0.007533  0.002197
# 2    -0.005052  0.001346 -0.000945 -0.000649 -0.006627  0.007116  0.000629
# 3     0.000910  0.002240 -0.001033 -0.000541 -0.009433  0.008187  0.011064
# 4     0.001229 -0.000389 -0.001622  0.000046  0.007877 -0.007774  0.002100
# ...        ...       ...       ...       ...       ...       ...       ...
# 1798  0.001880  0.001981  0.005436  0.001580  0.003855 -0.000024 -0.005024
# 1799  0.000056  0.000375  0.004032 -0.000524  0.000414  0.002463 -0.001466
# 1800  0.000000 -0.000153  0.006195 -0.001149 -0.001747 -0.003735  0.011787
# 1801  0.000000  0.000845 -0.002146 -0.001534 -0.001463  0.000183 -0.001383
# 1802 -0.000140  0.000845 -0.002146  0.000924  0.000337  0.000183  0.004148
#
#            PEN       NOK       ZAR  ...       ISK       DZD       PGK  \
# 0     0.002674  0.009029  0.024472  ...  0.004625  0.003121  0.000000
# 1     0.001638 -0.000024  0.009561  ... -0.002233  0.003724  0.038835
# 2    -0.002381  0.000287  0.008627  ...  0.003890  0.000170  0.000000
# 3    -0.001663 -0.000126  0.002932  ...  0.001743  0.001018 -0.038835
# 4     0.002555  0.001569  0.013339  ... -0.000830  0.001019  2.414702
# ...        ...       ...       ...  ...       ...       ...       ...
# 1798 -0.015778 -0.002430  0.005215  ...  0.002320  0.005197  0.001490
# 1799  0.003456 -0.000455 -0.001302  ... -0.003891 -0.000255 -0.020724
# 1800  0.000000  0.007453  0.003834  ... -0.001569  0.001286  0.020480
# 1801  0.001646 -0.006147 -0.003696  ...  0.003140  0.001101 -0.000122
# 1802  0.001646  0.004320  0.004079  ...  0.003140  0.001101 -0.030282
#
#            TWD       THB       AUD       IDR       KRW       MYR       NZD
# 0     0.010105  0.005485  0.017074  0.008412  0.010502  0.001316  0.019092
# 1     0.000915  0.002434 -0.000951  0.008176  0.011536  0.003958 -0.000313
# 2    -0.003361 -0.003041  0.002032  0.001634 -0.004880 -0.003120  0.001710
# 3     0.000424  0.000608  0.004243  0.006158  0.001437  0.002279  0.012075
# 4     0.003690  0.003683  0.004450  0.015706  0.004098  0.003465  0.006445
# ...        ...       ...       ...       ...       ...       ...       ...
# 1798 -0.000466 -0.000621  0.004260  0.005697  0.006681  0.001186  0.000572
# 1799  0.000529 -0.007732  0.004354 -0.003302 -0.002726  0.001544  0.002501
# 1800 -0.000161  0.002159  0.000725  0.002334  0.000948  0.000238  0.004444
# 1801  0.002203  0.002163 -0.002635  0.002563 -0.002714  0.000476 -0.000396
# 1802  0.002203  0.002163  0.001248  0.004316  0.000021 -0.000476  0.002366
#
# [1803 rows x 42 columns]

# %%
## these are anchors with neighbors, copy and pasted from 2 - Unsupervised Learning

'''g = {"CNY": ["CDF", "LAK", "TZS", "CLP", "GNF", "PKR", "PHP", "VND", "MRU"],
     "EUR": ["ALL", "CZK", "TND", "RON", "HUF", "PLN", "RSD", "SEK", "ISK", "DZD"],
     "JPY": ["PGK", "TWD", "THB", "AUD", "IDR", "KRW", "MYR", "NZD"],}'''


     g = {'CNY': ['VND', 'MRU', 'CDF', 'PKR'],
      'EUR': ['ALL', 'CZK', 'TND', 'RON', 'RSD', 'DZD', 'HUF', 'SEK', 'ISK', 'PLN'],
      'JPY': ['MYR', 'TWD', 'THB', 'IDR', 'AUD']}
# Out:
#   Cell In[4], line 8
#     g = {'CNY': ['VND', 'MRU', 'CDF', 'PKR'],
#     ^
# IndentationError: unexpected indent

# %%
# ## Need to think this through before proceeding.
# ## https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.XGBClassifier

# preparing dataframe to split

max_lag = 10
rolling_window = (10, 50)
seed = 42

def anchors_for_target(target: str, gmap: dict)-> list[str]:
    return [a for a, neighs in gmap.items() if target in neighs]

def make_panel_for_target(
    df_all: pd.DataFrame, target: str, gmap: dict,
    max_lag = 10, rolling_window = (10, 50)) -> pd.DataFrame:

    anchors = anchors_for_target(target, gmap)

    cols = {target}

    for a in anchors:
        if a in df_all.columns:
            cols.add(a)
        for n in gmap.get(a, []):
            if n in df_all.columns:
                cols.add(n)
    use_cols = sorted(cols)
    df = df_all[use_cols].copy()

    # using shift(-1) per below. 
    df["target"] = df[target].shift(-1)

    # create lags
    for col in use_cols:
        for l in range(1, max_lag + 1):
            df[f"{col}_lag_{l}"] = df[col].shift(l)


    # create rolling windows
    for col in use_cols:
        for w in rolling_window:
            df[f"{col}_ma{w}"] = df[col].rolling(w).mean().shift(1)
    return df.dropna().copy()

# %%
test = make_panel_for_target(lreturn, "CDF", g, max_lag = max_lag, rolling_window = rolling_window)
test

######. Guys, see if this is what we want, the entire df with lag and rolling window!!
# Out:
#            CDF       CLP       CNY       GNF       LAK       MRU       PHP  \
# 50    0.003766 -0.000148  0.004131 -0.000818  0.000240  0.000000  0.001821
# 51   -0.000629  0.001778  0.003764  0.000000 -0.022968  0.000000 -0.001074
# 52    0.000629  0.001781 -0.000754  0.001106  0.000000  0.008333  0.001439
# 53   -0.003766 -0.002670  0.002382  0.001107 -0.000586 -0.001394 -0.000480
# 54    0.000627  0.009676 -0.000740 -0.002212  0.000469 -0.001392  0.001459
# ...        ...       ...       ...       ...       ...       ...       ...
# 1793  0.038308 -0.000890 -0.000155 -0.004807 -0.003947 -0.009477  0.005001
# 1794  0.001827  0.008089  0.000337  0.000000  0.000000  0.000000 -0.006907
# 1795  0.000000 -0.004126 -0.002794  0.000000  0.001161  0.000000 -0.007450
# 1796 -0.040134 -0.007013 -0.000322 -0.000578  0.000000 -0.000251 -0.007463
# 1797  0.055892 -0.007013  0.000210  0.000116 -0.001625  0.001005 -0.007463
#
#            PKR       TZS       VND  ...  MRU_ma10  MRU_ma50  PHP_ma10  \
# 50    0.000143 -0.001176  0.000000  ... -0.000416 -0.000223  0.000974
# 51   -0.000072  0.000131  0.000000  ... -0.000416 -0.000223  0.000886
# 52    0.000072  0.000958  0.000000  ... -0.000416 -0.000223  0.000659
# 53    0.009414 -0.002263  0.000000  ...  0.000418 -0.000050  0.000755
# 54   -0.009557  0.000130  0.000000  ...  0.000278 -0.000078  0.000669
# ...        ...       ...       ...  ...       ...       ...       ...
# 1793  0.005554  0.001259 -0.001517  ... -0.000169 -0.000144 -0.000778
# 1794 -0.000178  0.001014  0.000000  ...  0.000075 -0.000116 -0.000285
# 1795  0.000533  0.000000  0.000000  ...  0.000100 -0.000111 -0.000364
# 1796  0.000000  0.004065  0.000568  ...  0.000100 -0.000111 -0.001053
# 1797 -0.000213  0.010641 -0.000190  ...  0.000025 -0.000362 -0.001701
#
#       PHP_ma50  PKR_ma10  PKR_ma50      TZS_ma10  TZS_ma50      VND_ma10  \
# 50    0.000416 -0.001680 -0.001266  1.062247e-17 -0.000085  2.110442e-04
# 51    0.000382 -0.001666 -0.001135 -4.230797e-04 -0.000109 -2.802687e-05
# 52    0.000372 -0.000949 -0.001098 -8.274541e-05 -0.000099 -4.667490e-18
# 53    0.000386 -0.000043 -0.000909 -8.723204e-06 -0.000077 -1.466954e-04
# 54    0.000300  0.000898 -0.000713 -2.437466e-04 -0.000131  0.000000e+00
# ...        ...       ...       ...           ...       ...           ...
# 1793 -0.000232 -0.000395  0.000012  1.251510e-03  0.000958  7.585941e-05
# 1794 -0.000066  0.000107  0.000230  1.252188e-03  0.000983 -3.789367e-05
# 1795 -0.000177  0.000018  0.000226  8.520155e-04  0.001162 -1.326945e-04
# 1796 -0.000568  0.000071  0.000255 -1.331400e-17  0.001181 -9.476003e-05
# 1797 -0.000303  0.000089  0.000145  2.034591e-04  0.000865 -1.895226e-05
#
#       VND_ma50
# 50    0.000101
# 51    0.000098
# 52    0.000097
# 53    0.000091
# 54    0.000083
# ...        ...
# 1793 -0.000188
# 1794 -0.000225
# 1795 -0.000209
# 1796 -0.000194
# 1797 -0.000187
#
# [1748 rows x 81 columns]

# %%
# do prediction, confusion matrix for classification and regression

# %%
# we can determin how to split the data into good proportion

# %%
# run functions

# %%
# above code is still in developement and testing

# %%
import xgboost as xgb
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# Load the data
df_0 = pd.read_parquet('fx_log_return.parquet')[['CNY', 'CDF']]
df_0.head()

# Starting with CNY/CDF as an example
df_0['target'] = df_0['CDF'].shift(-1)

# Dropping all NA
df_0.dropna(inplace=True)

df_0.head()
# Out:
#         CNY       CDF    target
# 0  0.007527  0.000000 -0.000637
# 1  0.004706 -0.000637  0.000637
# 2 -0.005052  0.000637 -0.000637
# 3  0.000910 -0.000637  0.000637
# 4  0.001229  0.000637 -0.000637

# %%
# Create lag features (e.g., previous 5 days' returns)
for i in range(1, 6):
    df_0[f'Return_lag_{i}'] = df_0['CDF'].pct_change().shift(i)

# Create moving average features
df_0['MA_10'] = df_0['CDF'].rolling(window=10).mean().shift(1)
df_0['MA_50'] = df_0['CDF'].rolling(window=50).mean().shift(1)

# Drop initial rows with NaNs created by rolling windows
df_0.dropna(inplace=True)
df_0.head()
df_0 = df_0.replace([np.inf, -np.inf], np.nan).fillna(0)
df_0
# Out:
#            CNY       CDF    target  Return_lag_1  Return_lag_2  Return_lag_3  \
# 50    0.004131  0.003766 -0.000629      0.000000     -1.000000     -2.000000
# 51    0.003764 -0.000629  0.000629     -7.009225      0.000000     -1.000000
# 52   -0.000754  0.000629 -0.003766     -1.166922     -7.009225      0.000000
# 53    0.002382 -0.003766  0.000627     -2.000000     -1.166922     -7.009225
# 54   -0.000740  0.000627  0.000000     -6.990834     -2.000000     -1.166922
# ...        ...       ...       ...           ...           ...           ...
# 1788  0.000800  0.016646  0.003578     -2.000000     -2.124805      0.603662
# 1789  0.000604  0.003578  0.000000      4.274081     -2.000000     -2.124805
# 1790  0.001533  0.000000  0.000000     -0.785070      4.274081     -2.000000
# 1791 -0.001350  0.000000 -0.020224     -1.000000     -0.785070      4.274081
# 1797  0.000210  0.055892  0.055892      0.000000     -1.000000     -0.952319
#
#       Return_lag_4  Return_lag_5         MA_10     MA_50
# 50        0.000000     -1.000000  2.511012e-17 -0.000328
# 51       -2.000000      0.000000  3.139691e-04 -0.000253
# 52       -1.000000     -2.000000  2.510985e-04 -0.000253
# 53        0.000000     -1.000000  3.139691e-04 -0.000253
# 54       -7.009225      0.000000  2.645453e-17 -0.000316
# ...            ...           ...           ...       ...
# 1788     -1.293499      0.000000  1.053190e-04  0.000126
# 1789      0.603662     -1.293499  1.594361e-03  0.000459
# 1790     -2.124805      0.603662  2.022414e-03  0.000538
# 1791     -2.000000     -2.124805  1.776246e-03  0.000538
# 1797     -2.894163      0.000000  3.156254e-04  0.000133
#
# [1049 rows x 10 columns]

# %%
# Define features (X) and target (y)
features = [col for col in df_0.columns if col not in ['target']]
X = df_0[features]
y = df_0['target']

# Time-based train-test split
split_index = int(len(X) * 0.8)
X_train, X_test = X[:split_index], X[split_index:]
y_train, y_test = y[:split_index], y[split_index:]

xgb = XGBRegressor()
parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:squarederror'],
              'learning_rate': [.03, .24, .8],
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'subsample': [.2, .5, .8],
              'colsample_bytree': [.7],
              'n_estimators': [2, 5, 10],
              }

xgb_grid = GridSearchCV(xgb,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

xgb_grid.fit(X_train,
             y_train)

print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# Fitting 2 folds for each of 81 candidates, totalling 162 fits
# 0.005328415080134541
# {'colsample_bytree': 0.7, 'learning_rate': 0.03, 'max_depth': 7, 'min_child_weight': 4, 'n_estimators': 2, 'nthread': 4, 'objective': 'reg:squarederror', 'subsample': 0.8}

# %% [markdown]
# # Granger Causality

# %%
lreturn = pd.read_parquet('/work/fx_log_return.parquet')

g = {"CNY": ["CDF", "LAK", "TZS", "CLP", "GNF", "PKR", "PHP", "VND", "MRU"],
     "EUR": ["ALL", "CZK", "TND", "RON", "HUF", "PLN", "RSD", "SEK", "ISK", "DZD"],
     "JPY": ["PGK", "TWD", "THB", "AUD", "IDR", "KRW", "MYR", "NZD"]}

def granger(res, g, ml=5, a=0.05):
    x = []
    for i, j in g.items():
        for k in j:
            if i not in res.columns or k not in res.columns:
                continue
            df = pd.concat([res[k], res[i]], axis=1).dropna()
            df.columns = ["neighbor", "anchor"]
            if len(df) <= ml * 3:
                continue
            t = grangercausalitytests(df, maxlag=ml)
            pval = [t[lag][0]['ssr_ftest'][1] for lag in range(1, ml + 1)]
            min_p = float(np.min(pval))
            best_lag = int(np.argmin(pval) + 1)
            x.append({"anchor": i,
                    "neighbor": k,
                    "min_pval": round(min_p, 4),
                    "best_lag (days)": best_lag,
                    "significant": (min_p < a)})
    rdf = pd.DataFrame(x)
    return rdf

rdf = granger(lreturn,g,10,0.05)
rdf = rdf.sort_values(["anchor", "min_pval"]).reset_index(drop=True)
an = rdf[rdf["significant"]==True].sort_values(["anchor", "min_pval"])
ng = (an.groupby("anchor")["neighbor"].apply(list).to_dict())
ng
# Out:
# number of lags (no zero) 8
# ssr based F test:         F=3.9530  , p=0.0001  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=31.9262 , p=0.0001  , df=8
# likelihood ratio test: chi2=31.6456 , p=0.0001  , df=8
# parameter F test:         F=3.9530  , p=0.0001  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=3.5400  , p=0.0002  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=32.2009 , p=0.0002  , df=9
# likelihood ratio test: chi2=31.9153 , p=0.0002  , df=9
# parameter F test:         F=3.5400  , p=0.0002  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.3821  , p=0.0002  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=34.2218 , p=0.0002  , df=10
# likelihood ratio test: chi2=33.8993 , p=0.0002  , df=10
# parameter F test:         F=3.3821  , p=0.0002  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=6.8430  , p=0.0090  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=6.8544  , p=0.0088  , df=1
# likelihood ratio test: chi2=6.8414  , p=0.0089  , df=1
# parameter F test:         F=6.8430  , p=0.0090  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=6.1682  , p=0.0021  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=12.3707 , p=0.0021  , df=2
# likelihood ratio test: chi2=12.3284 , p=0.0021  , df=2
# parameter F test:         F=6.1682  , p=0.0021  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=6.0743  , p=0.0004  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=18.2942 , p=0.0004  , df=3
# likelihood ratio test: chi2=18.2018 , p=0.0004  , df=3
# parameter F test:         F=6.0743  , p=0.0004  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=4.5770  , p=0.0011  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=18.4002 , p=0.0010  , df=4
# likelihood ratio test: chi2=18.3067 , p=0.0011  , df=4
# parameter F test:         F=4.5770  , p=0.0011  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.7593  , p=0.0022  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=18.9121 , p=0.0020  , df=5
# likelihood ratio test: chi2=18.8133 , p=0.0021  , df=5
# parameter F test:         F=3.7593  , p=0.0022  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.4974  , p=0.0019  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=21.1371 , p=0.0017  , df=6
# likelihood ratio test: chi2=21.0137 , p=0.0018  , df=6
# parameter F test:         F=3.4974  , p=0.0019  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.0935  , p=0.0030  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=21.8368 , p=0.0027  , df=7
# likelihood ratio test: chi2=21.7051 , p=0.0029  , df=7
# parameter F test:         F=3.0935  , p=0.0030  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.7223  , p=0.0055  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=21.9864 , p=0.0049  , df=8
# likelihood ratio test: chi2=21.8528 , p=0.0052  , df=8
# parameter F test:         F=2.7223  , p=0.0055  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.8027  , p=0.0029  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=25.4941 , p=0.0025  , df=9
# likelihood ratio test: chi2=25.3147 , p=0.0026  , df=9
# parameter F test:         F=2.8027  , p=0.0029  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=3.4823  , p=0.0001  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=35.2358 , p=0.0001  , df=10
# likelihood ratio test: chi2=34.8940 , p=0.0001  , df=10
# parameter F test:         F=3.4823  , p=0.0001  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.1308  , p=0.0770  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=3.1361  , p=0.0766  , df=1
# likelihood ratio test: chi2=3.1333  , p=0.0767  , df=1
# parameter F test:         F=3.1308  , p=0.0770  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=2.1381  , p=0.1182  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=4.2881  , p=0.1172  , df=2
# likelihood ratio test: chi2=4.2830  , p=0.1175  , df=2
# parameter F test:         F=2.1381  , p=0.1182  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.4420  , p=0.2287  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=4.3430  , p=0.2267  , df=3
# likelihood ratio test: chi2=4.3377  , p=0.2272  , df=3
# parameter F test:         F=1.4420  , p=0.2287  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.0819  , p=0.3638  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=4.3493  , p=0.3608  , df=4
# likelihood ratio test: chi2=4.3441  , p=0.3614  , df=4
# parameter F test:         F=1.0819  , p=0.3638  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.6273  , p=0.1495  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=8.1867  , p=0.1462  , df=5
# likelihood ratio test: chi2=8.1682  , p=0.1472  , df=5
# parameter F test:         F=1.6273  , p=0.1495  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.8357  , p=0.0886  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=11.0943 , p=0.0855  , df=6
# likelihood ratio test: chi2=11.0602 , p=0.0865  , df=6
# parameter F test:         F=1.8357  , p=0.0886  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.6242  , p=0.1241  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=11.4651 , p=0.1196  , df=7
# likelihood ratio test: chi2=11.4286 , p=0.1210  , df=7
# parameter F test:         F=1.6242  , p=0.1241  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.0048  , p=0.0425  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=16.1915 , p=0.0397  , df=8
# likelihood ratio test: chi2=16.1190 , p=0.0407  , df=8
# parameter F test:         F=2.0048  , p=0.0425  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0977  , p=0.0268  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=19.0818 , p=0.0245  , df=9
# likelihood ratio test: chi2=18.9810 , p=0.0254  , df=9
# parameter F test:         F=2.0977  , p=0.0268  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.9856  , p=0.0313  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=20.0914 , p=0.0284  , df=10
# likelihood ratio test: chi2=19.9796 , p=0.0294  , df=10
# parameter F test:         F=1.9856  , p=0.0313  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=133.6913, p=0.0000  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=133.9142, p=0.0000  , df=1
# likelihood ratio test: chi2=129.1719, p=0.0000  , df=1
# parameter F test:         F=133.6913, p=0.0000  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=100.8586, p=0.0000  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=202.2788, p=0.0000  , df=2
# likelihood ratio test: chi2=191.7041, p=0.0000  , df=2
# parameter F test:         F=100.8586, p=0.0000  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=79.5621 , p=0.0000  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=239.6181, p=0.0000  , df=3
# likelihood ratio test: chi2=224.9566, p=0.0000  , df=3
# parameter F test:         F=79.5621 , p=0.0000  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=82.0361 , p=0.0000  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=329.7942, p=0.0000  , df=4
# likelihood ratio test: chi2=302.8163, p=0.0000  , df=4
# parameter F test:         F=82.0361 , p=0.0000  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=59.6156 , p=0.0000  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=299.9128, p=0.0000  , df=5
# likelihood ratio test: chi2=277.3739, p=0.0000  , df=5
# parameter F test:         F=59.6156 , p=0.0000  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=48.0952 , p=0.0000  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=290.6739, p=0.0000  , df=6
# likelihood ratio test: chi2=269.4276, p=0.0000  , df=6
# parameter F test:         F=48.0952 , p=0.0000  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=40.5422 , p=0.0000  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=286.1856, p=0.0000  , df=7
# likelihood ratio test: chi2=265.5496, p=0.0000  , df=7
# parameter F test:         F=40.5422 , p=0.0000  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=35.8805 , p=0.0000  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=289.7887, p=0.0000  , df=8
# likelihood ratio test: chi2=268.6441, p=0.0000  , df=8
# parameter F test:         F=35.8805 , p=0.0000  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=34.7537 , p=0.0000  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=316.1317, p=0.0000  , df=9
# likelihood ratio test: chi2=291.1708, p=0.0000  , df=9
# parameter F test:         F=34.7537 , p=0.0000  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=29.8578 , p=0.0000  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=302.1167, p=0.0000  , df=10
# likelihood ratio test: chi2=279.2043, p=0.0000  , df=10
# parameter F test:         F=29.8578 , p=0.0000  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=10.5836 , p=0.0012  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=10.6012 , p=0.0011  , df=1
# likelihood ratio test: chi2=10.5701 , p=0.0011  , df=1
# parameter F test:         F=10.5836 , p=0.0012  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.2921  , p=0.0051  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=10.6136 , p=0.0050  , df=2
# likelihood ratio test: chi2=10.5825 , p=0.0050  , df=2
# parameter F test:         F=5.2921  , p=0.0051  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.4214  , p=0.0042  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=13.3160 , p=0.0040  , df=3
# likelihood ratio test: chi2=13.2670 , p=0.0041  , df=3
# parameter F test:         F=4.4214  , p=0.0042  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.3753  , p=0.0092  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=13.5692 , p=0.0088  , df=4
# likelihood ratio test: chi2=13.5182 , p=0.0090  , df=4
# parameter F test:         F=3.3753  , p=0.0092  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.1401  , p=0.0079  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=15.7970 , p=0.0074  , df=5
# likelihood ratio test: chi2=15.7280 , p=0.0077  , df=5
# parameter F test:         F=3.1401  , p=0.0079  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.0176  , p=0.0061  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=18.2378 , p=0.0057  , df=6
# likelihood ratio test: chi2=18.1459 , p=0.0059  , df=6
# parameter F test:         F=3.0176  , p=0.0061  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.4784  , p=0.0156  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=17.4948 , p=0.0145  , df=7
# likelihood ratio test: chi2=17.4102 , p=0.0149  , df=7
# parameter F test:         F=2.4784  , p=0.0156  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.1999  , p=0.0249  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=17.7673 , p=0.0230  , df=8
# likelihood ratio test: chi2=17.6799 , p=0.0238  , df=8
# parameter F test:         F=2.1999  , p=0.0249  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9904  , p=0.0368  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=18.1057 , p=0.0340  , df=9
# likelihood ratio test: chi2=18.0149 , p=0.0350  , df=9
# parameter F test:         F=1.9904  , p=0.0368  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8191  , p=0.0527  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=18.4070 , p=0.0485  , df=10
# likelihood ratio test: chi2=18.3131 , p=0.0499  , df=10
# parameter F test:         F=1.8191  , p=0.0527  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=9.9547  , p=0.0016  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=9.9713  , p=0.0016  , df=1
# likelihood ratio test: chi2=9.9438  , p=0.0016  , df=1
# parameter F test:         F=9.9547  , p=0.0016  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.2667  , p=0.0052  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=10.5627 , p=0.0051  , df=2
# likelihood ratio test: chi2=10.5319 , p=0.0052  , df=2
# parameter F test:         F=5.2667  , p=0.0052  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=5.0418  , p=0.0018  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=15.1845 , p=0.0017  , df=3
# likelihood ratio test: chi2=15.1208 , p=0.0017  , df=3
# parameter F test:         F=5.0418  , p=0.0018  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.8909  , p=0.0038  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=15.6419 , p=0.0035  , df=4
# likelihood ratio test: chi2=15.5743 , p=0.0036  , df=4
# parameter F test:         F=3.8909  , p=0.0038  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=3.7186  , p=0.0024  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=18.7073 , p=0.0022  , df=5
# likelihood ratio test: chi2=18.6106 , p=0.0023  , df=5
# parameter F test:         F=3.7186  , p=0.0024  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=3.2403  , p=0.0036  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=19.5835 , p=0.0033  , df=6
# likelihood ratio test: chi2=19.4775 , p=0.0034  , df=6
# parameter F test:         F=3.2403  , p=0.0036  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=3.0223  , p=0.0037  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=21.3344 , p=0.0033  , df=7
# likelihood ratio test: chi2=21.2087 , p=0.0035  , df=7
# parameter F test:         F=3.0223  , p=0.0037  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.6836  , p=0.0062  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=21.6744 , p=0.0056  , df=8
# likelihood ratio test: chi2=21.5446 , p=0.0058  , df=8
# parameter F test:         F=2.6836  , p=0.0062  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.4132  , p=0.0101  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=21.9511 , p=0.0090  , df=9
# likelihood ratio test: chi2=21.8179 , p=0.0095  , df=9
# parameter F test:         F=2.4132  , p=0.0101  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.2162  , p=0.0147  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=22.4249 , p=0.0131  , df=10
# likelihood ratio test: chi2=22.2858 , p=0.0137  , df=10
# parameter F test:         F=2.2162  , p=0.0147  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=100.7433, p=0.0000  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=100.9113, p=0.0000  , df=1
# likelihood ratio test: chi2=98.1871 , p=0.0000  , df=1
# parameter F test:         F=100.7433, p=0.0000  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=59.4501 , p=0.0000  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=119.2311, p=0.0000  , df=2
# likelihood ratio test: chi2=115.4504, p=0.0000  , df=2
# parameter F test:         F=59.4501 , p=0.0000  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=41.2901 , p=0.0000  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=124.3538, p=0.0000  , df=3
# likelihood ratio test: chi2=120.2464, p=0.0000  , df=3
# parameter F test:         F=41.2901 , p=0.0000  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=31.8105 , p=0.0000  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=127.8818, p=0.0000  , df=4
# likelihood ratio test: chi2=123.5411, p=0.0000  , df=4
# parameter F test:         F=31.8105 , p=0.0000  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=27.4090 , p=0.0000  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=137.8884, p=0.0000  , df=5
# likelihood ratio test: chi2=132.8568, p=0.0000  , df=5
# parameter F test:         F=27.4090 , p=0.0000  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=24.7480 , p=0.0000  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=149.5701, p=0.0000  , df=6
# likelihood ratio test: chi2=143.6707, p=0.0000  , df=6
# parameter F test:         F=24.7480 , p=0.0000  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=22.9192 , p=0.0000  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=161.7859, p=0.0000  , df=7
# likelihood ratio test: chi2=154.9089, p=0.0000  , df=7
# parameter F test:         F=22.9192 , p=0.0000  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=20.4360 , p=0.0000  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=165.0514, p=0.0000  , df=8
# likelihood ratio test: chi2=157.8984, p=0.0000  , df=8
# parameter F test:         F=20.4360 , p=0.0000  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=18.1717 , p=0.0000  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=165.2957, p=0.0000  , df=9
# likelihood ratio test: chi2=158.1184, p=0.0000  , df=9
# parameter F test:         F=18.1717 , p=0.0000  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=17.1744 , p=0.0000  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=173.7792, p=0.0000  , df=10
# likelihood ratio test: chi2=165.8652, p=0.0000  , df=10
# parameter F test:         F=17.1744 , p=0.0000  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.1130  , p=0.7368  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=0.1131  , p=0.7366  , df=1
# likelihood ratio test: chi2=0.1131  , p=0.7366  , df=1
# parameter F test:         F=0.1130  , p=0.7368  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.0273  , p=0.9731  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=0.0547  , p=0.9730  , df=2
# likelihood ratio test: chi2=0.0547  , p=0.9730  , df=2
# parameter F test:         F=0.0273  , p=0.9731  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.1121  , p=0.9531  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=0.3376  , p=0.9528  , df=3
# likelihood ratio test: chi2=0.3375  , p=0.9528  , df=3
# parameter F test:         F=0.1121  , p=0.9531  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.1351  , p=0.9694  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=0.5431  , p=0.9692  , df=4
# likelihood ratio test: chi2=0.5431  , p=0.9692  , df=4
# parameter F test:         F=0.1351  , p=0.9694  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.2321  , p=0.9485  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=1.1678  , p=0.9479  , df=5
# likelihood ratio test: chi2=1.1674  , p=0.9480  , df=5
# parameter F test:         F=0.2321  , p=0.9485  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.9273  , p=0.4741  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=5.6044  , p=0.4689  , df=6
# likelihood ratio test: chi2=5.5957  , p=0.4700  , df=6
# parameter F test:         F=0.9273  , p=0.4741  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.1748  , p=0.3139  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=8.2928  , p=0.3075  , df=7
# likelihood ratio test: chi2=8.2737  , p=0.3091  , df=7
# parameter F test:         F=1.1748  , p=0.3139  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1749  , p=0.3104  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=9.4892  , p=0.3027  , df=8
# likelihood ratio test: chi2=9.4642  , p=0.3047  , df=8
# parameter F test:         F=1.1749  , p=0.3104  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=0.9416  , p=0.4875  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=8.5649  , p=0.4784  , df=9
# likelihood ratio test: chi2=8.5445  , p=0.4803  , df=9
# parameter F test:         F=0.9416  , p=0.4875  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.8161  , p=0.6131  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=8.2582  , p=0.6036  , df=10
# likelihood ratio test: chi2=8.2392  , p=0.6055  , df=10
# parameter F test:         F=0.8161  , p=0.6131  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=5.3001  , p=0.0214  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=5.3089  , p=0.0212  , df=1
# likelihood ratio test: chi2=5.3011  , p=0.0213  , df=1
# parameter F test:         F=5.3001  , p=0.0214  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=3.4433  , p=0.0322  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=6.9058  , p=0.0317  , df=2
# likelihood ratio test: chi2=6.8926  , p=0.0319  , df=2
# parameter F test:         F=3.4433  , p=0.0322  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=2.3058  , p=0.0750  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=6.9444  , p=0.0737  , df=3
# likelihood ratio test: chi2=6.9310  , p=0.0741  , df=3
# parameter F test:         F=2.3058  , p=0.0750  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.2998  , p=0.0105  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=13.2657 , p=0.0100  , df=4
# likelihood ratio test: chi2=13.2170 , p=0.0103  , df=4
# parameter F test:         F=3.2998  , p=0.0105  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.7254  , p=0.0185  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=13.7107 , p=0.0176  , df=5
# likelihood ratio test: chi2=13.6587 , p=0.0179  , df=5
# parameter F test:         F=2.7254  , p=0.0185  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2346  , p=0.0375  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=13.5055 , p=0.0357  , df=6
# likelihood ratio test: chi2=13.4550 , p=0.0364  , df=6
# parameter F test:         F=2.2346  , p=0.0375  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.9958  , p=0.0523  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=14.0881 , p=0.0496  , df=7
# likelihood ratio test: chi2=14.0331 , p=0.0506  , df=7
# parameter F test:         F=1.9958  , p=0.0523  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.9894  , p=0.0443  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=16.0673 , p=0.0414  , df=8
# likelihood ratio test: chi2=15.9958 , p=0.0424  , df=8
# parameter F test:         F=1.9894  , p=0.0443  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.9320  , p=0.0437  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=17.5739 , p=0.0405  , df=9
# likelihood ratio test: chi2=17.4884 , p=0.0416  , df=9
# parameter F test:         F=1.9320  , p=0.0437  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.9033  , p=0.0013  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=29.3774 , p=0.0011  , df=10
# likelihood ratio test: chi2=29.1393 , p=0.0012  , df=10
# parameter F test:         F=2.9033  , p=0.0013  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.9444  , p=0.3313  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=0.9460  , p=0.3307  , df=1
# likelihood ratio test: chi2=0.9457  , p=0.3308  , df=1
# parameter F test:         F=0.9444  , p=0.3313  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.5056  , p=0.2222  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=3.0197  , p=0.2209  , df=2
# likelihood ratio test: chi2=3.0171  , p=0.2212  , df=2
# parameter F test:         F=1.5056  , p=0.2222  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.1327  , p=0.3345  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=3.4114  , p=0.3324  , df=3
# likelihood ratio test: chi2=3.4082  , p=0.3329  , df=3
# parameter F test:         F=1.1327  , p=0.3345  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3622  , p=0.2447  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=5.4763  , p=0.2418  , df=4
# likelihood ratio test: chi2=5.4680  , p=0.2426  , df=4
# parameter F test:         F=1.3622  , p=0.2447  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.5556  , p=0.0259  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=12.8569 , p=0.0248  , df=5
# likelihood ratio test: chi2=12.8111 , p=0.0252  , df=5
# parameter F test:         F=2.5556  , p=0.0259  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.2304  , p=0.0378  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=13.4801 , p=0.0360  , df=6
# likelihood ratio test: chi2=13.4298 , p=0.0367  , df=6
# parameter F test:         F=2.2304  , p=0.0378  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.1570  , p=0.0353  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=15.2261 , p=0.0332  , df=7
# likelihood ratio test: chi2=15.1619 , p=0.0340  , df=7
# parameter F test:         F=2.1570  , p=0.0353  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.9559  , p=0.0027  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=23.8734 , p=0.0024  , df=8
# likelihood ratio test: chi2=23.7160 , p=0.0026  , df=8
# parameter F test:         F=2.9559  , p=0.0027  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.6899  , p=0.0042  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=24.4678 , p=0.0036  , df=9
# likelihood ratio test: chi2=24.3025 , p=0.0038  , df=9
# parameter F test:         F=2.6899  , p=0.0042  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.6588  , p=0.0032  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=26.9036 , p=0.0027  , df=10
# likelihood ratio test: chi2=26.7037 , p=0.0029  , df=10
# parameter F test:         F=2.6588  , p=0.0032  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=1.4845  , p=0.2232  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=1.4870  , p=0.2227  , df=1
# likelihood ratio test: chi2=1.4863  , p=0.2228  , df=1
# parameter F test:         F=1.4845  , p=0.2232  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7323  , p=0.1772  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=3.4743  , p=0.1760  , df=2
# likelihood ratio test: chi2=3.4709  , p=0.1763  , df=2
# parameter F test:         F=1.7323  , p=0.1772  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.7955  , p=0.1460  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=5.4075  , p=0.1443  , df=3
# likelihood ratio test: chi2=5.3994  , p=0.1448  , df=3
# parameter F test:         F=1.7955  , p=0.1460  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=1.3940  , p=0.2336  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=5.6041  , p=0.2307  , df=4
# likelihood ratio test: chi2=5.5954  , p=0.2315  , df=4
# parameter F test:         F=1.3940  , p=0.2336  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=1.1618  , p=0.3257  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=5.8447  , p=0.3216  , df=5
# likelihood ratio test: chi2=5.8352  , p=0.3226  , df=5
# parameter F test:         F=1.1618  , p=0.3257  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=1.1487  , p=0.3315  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=6.9422  , p=0.3262  , df=6
# likelihood ratio test: chi2=6.9288  , p=0.3275  , df=6
# parameter F test:         F=1.1487  , p=0.3315  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=1.0344  , p=0.4047  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=7.3019  , p=0.3981  , df=7
# likelihood ratio test: chi2=7.2871  , p=0.3996  , df=7
# parameter F test:         F=1.0344  , p=0.4047  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.2600  , p=0.0211  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=18.2527 , p=0.0194  , df=8
# likelihood ratio test: chi2=18.1605 , p=0.0201  , df=8
# parameter F test:         F=2.2600  , p=0.0211  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.0287  , p=0.0329  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=18.4541 , p=0.0303  , df=9
# likelihood ratio test: chi2=18.3599 , p=0.0312  , df=9
# parameter F test:         F=2.0287  , p=0.0329  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.8842  , p=0.0431  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=19.0656 , p=0.0394  , df=10
# likelihood ratio test: chi2=18.9649 , p=0.0407  , df=10
# parameter F test:         F=1.8842  , p=0.0431  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=8.7510  , p=0.0031  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=8.7656  , p=0.0031  , df=1
# likelihood ratio test: chi2=8.7444  , p=0.0031  , df=1
# parameter F test:         F=8.7510  , p=0.0031  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=5.7246  , p=0.0033  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=11.4810 , p=0.0032  , df=2
# likelihood ratio test: chi2=11.4446 , p=0.0033  , df=2
# parameter F test:         F=5.7246  , p=0.0033  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=4.2423  , p=0.0054  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=12.7766 , p=0.0051  , df=3
# likelihood ratio test: chi2=12.7315 , p=0.0053  , df=3
# parameter F test:         F=4.2423  , p=0.0054  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=3.1792  , p=0.0130  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=12.7807 , p=0.0124  , df=4
# likelihood ratio test: chi2=12.7355 , p=0.0126  , df=4
# parameter F test:         F=3.1792  , p=0.0130  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=2.6310  , p=0.0223  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=13.2360 , p=0.0213  , df=5
# likelihood ratio test: chi2=13.1875 , p=0.0217  , df=5
# parameter F test:         F=2.6310  , p=0.0223  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=2.3122  , p=0.0315  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=13.9746 , p=0.0299  , df=6
# likelihood ratio test: chi2=13.9205 , p=0.0305  , df=6
# parameter F test:         F=2.3122  , p=0.0315  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=2.3891  , p=0.0197  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=16.8646 , p=0.0183  , df=7
# likelihood ratio test: chi2=16.7859 , p=0.0188  , df=7
# parameter F test:         F=2.3891  , p=0.0197  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=2.5381  , p=0.0095  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=20.4988 , p=0.0086  , df=8
# likelihood ratio test: chi2=20.3827 , p=0.0090  , df=8
# parameter F test:         F=2.5381  , p=0.0095  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=2.2964  , p=0.0146  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=20.8887 , p=0.0132  , df=9
# likelihood ratio test: chi2=20.7680 , p=0.0137  , df=9
# parameter F test:         F=2.2964  , p=0.0146  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=2.0663  , p=0.0241  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=20.9083 , p=0.0217  , df=10
# likelihood ratio test: chi2=20.7873 , p=0.0226  , df=10
# parameter F test:         F=2.0663  , p=0.0241  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=3.3032  , p=0.0693  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=3.3087  , p=0.0689  , df=1
# likelihood ratio test: chi2=3.3056  , p=0.0690  , df=1
# parameter F test:         F=3.3032  , p=0.0693  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=1.7750  , p=0.1698  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=3.5598  , p=0.1687  , df=2
# likelihood ratio test: chi2=3.5563  , p=0.1690  , df=2
# parameter F test:         F=1.7750  , p=0.1698  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=1.2112  , p=0.3042  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=3.6479  , p=0.3021  , df=3
# likelihood ratio test: chi2=3.6442  , p=0.3025  , df=3
# parameter F test:         F=1.2112  , p=0.3042  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.9767  , p=0.4191  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=3.9263  , p=0.4161  , df=4
# likelihood ratio test: chi2=3.9221  , p=0.4167  , df=4
# parameter F test:         F=0.9767  , p=0.4191  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.8344  , p=0.5251  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=4.1975  , p=0.5213  , df=5
# likelihood ratio test: chi2=4.1926  , p=0.5220  , df=5
# parameter F test:         F=0.8344  , p=0.5251  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8429  , p=0.5367  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=5.0941  , p=0.5318  , df=6
# likelihood ratio test: chi2=5.0869  , p=0.5327  , df=6
# parameter F test:         F=0.8429  , p=0.5367  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.7594  , p=0.6216  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=5.3604  , p=0.6161  , df=7
# likelihood ratio test: chi2=5.3524  , p=0.6170  , df=7
# parameter F test:         F=0.7594  , p=0.6216  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.0962  , p=0.3627  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=8.8538  , p=0.3548  , df=8
# likelihood ratio test: chi2=8.8320  , p=0.3567  , df=8
# parameter F test:         F=1.0962  , p=0.3627  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0341  , p=0.4100  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=9.4068  , p=0.4006  , df=9
# likelihood ratio test: chi2=9.3822  , p=0.4028  , df=9
# parameter F test:         F=1.0341  , p=0.4100  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=1.1514  , p=0.3198  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=11.6500 , p=0.3092  , df=10
# likelihood ratio test: chi2=11.6124 , p=0.3118  , df=10
# parameter F test:         F=1.1514  , p=0.3198  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=86.7614 , p=0.0000  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=86.9061 , p=0.0000  , df=1
# likelihood ratio test: chi2=84.8755 , p=0.0000  , df=1
# parameter F test:         F=86.7614 , p=0.0000  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=45.3348 , p=0.0000  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=90.9220 , p=0.0000  , df=2
# likelihood ratio test: chi2=88.7014 , p=0.0000  , df=2
# parameter F test:         F=45.3348 , p=0.0000  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=29.8559 , p=0.0000  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=89.9174 , p=0.0000  , df=3
# likelihood ratio test: chi2=87.7436 , p=0.0000  , df=3
# parameter F test:         F=29.8559 , p=0.0000  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=22.6293 , p=0.0000  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=90.9723 , p=0.0000  , df=4
# likelihood ratio test: chi2=88.7469 , p=0.0000  , df=4
# parameter F test:         F=22.6293 , p=0.0000  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=18.4515 , p=0.0000  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=92.8252 , p=0.0000  , df=5
# likelihood ratio test: chi2=90.5084 , p=0.0000  , df=5
# parameter F test:         F=18.4515 , p=0.0000  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=15.6848 , p=0.0000  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=94.7945 , p=0.0000  , df=6
# likelihood ratio test: chi2=92.3788 , p=0.0000  , df=6
# parameter F test:         F=15.6848 , p=0.0000  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=13.4750 , p=0.0000  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=95.1193 , p=0.0000  , df=7
# likelihood ratio test: chi2=92.6860 , p=0.0000  , df=7
# parameter F test:         F=13.4750 , p=0.0000  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=12.2467 , p=0.0000  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=98.9107 , p=0.0000  , df=8
# likelihood ratio test: chi2=96.2817 , p=0.0000  , df=8
# parameter F test:         F=12.2467 , p=0.0000  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=11.0166 , p=0.0000  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=100.2103, p=0.0000  , df=9
# likelihood ratio test: chi2=97.5116 , p=0.0000  , df=9
# parameter F test:         F=11.0166 , p=0.0000  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=10.2788 , p=0.0000  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=104.0066, p=0.0000  , df=10
# likelihood ratio test: chi2=101.1018, p=0.0000  , df=10
# parameter F test:         F=10.2788 , p=0.0000  , df_denom=1772, df_num=10
#
# Granger Causality
# number of lags (no zero) 1
# ssr based F test:         F=0.6256  , p=0.4291  , df_denom=1799, df_num=1
# ssr based chi2 test:   chi2=0.6266  , p=0.4286  , df=1
# likelihood ratio test: chi2=0.6265  , p=0.4286  , df=1
# parameter F test:         F=0.6256  , p=0.4291  , df_denom=1799, df_num=1
#
# Granger Causality
# number of lags (no zero) 2
# ssr based F test:         F=0.6131  , p=0.5418  , df_denom=1796, df_num=2
# ssr based chi2 test:   chi2=1.2296  , p=0.5408  , df=2
# likelihood ratio test: chi2=1.2291  , p=0.5409  , df=2
# parameter F test:         F=0.6131  , p=0.5418  , df_denom=1796, df_num=2
#
# Granger Causality
# number of lags (no zero) 3
# ssr based F test:         F=0.7247  , p=0.5372  , df_denom=1793, df_num=3
# ssr based chi2 test:   chi2=2.1826  , p=0.5354  , df=3
# likelihood ratio test: chi2=2.1813  , p=0.5356  , df=3
# parameter F test:         F=0.7247  , p=0.5372  , df_denom=1793, df_num=3
#
# Granger Causality
# number of lags (no zero) 4
# ssr based F test:         F=0.5588  , p=0.6926  , df_denom=1790, df_num=4
# ssr based chi2 test:   chi2=2.2465  , p=0.6905  , df=4
# likelihood ratio test: chi2=2.2451  , p=0.6908  , df=4
# parameter F test:         F=0.5588  , p=0.6926  , df_denom=1790, df_num=4
#
# Granger Causality
# number of lags (no zero) 5
# ssr based F test:         F=0.9037  , p=0.4777  , df_denom=1787, df_num=5
# ssr based chi2 test:   chi2=4.5463  , p=0.4737  , df=5
# likelihood ratio test: chi2=4.5406  , p=0.4745  , df=5
# parameter F test:         F=0.9037  , p=0.4777  , df_denom=1787, df_num=5
#
# Granger Causality
# number of lags (no zero) 6
# ssr based F test:         F=0.8654  , p=0.5196  , df_denom=1784, df_num=6
# ssr based chi2 test:   chi2=5.2302  , p=0.5146  , df=6
# likelihood ratio test: chi2=5.2226  , p=0.5156  , df=6
# parameter F test:         F=0.8654  , p=0.5196  , df_denom=1784, df_num=6
#
# Granger Causality
# number of lags (no zero) 7
# ssr based F test:         F=0.8421  , p=0.5523  , df_denom=1781, df_num=7
# ssr based chi2 test:   chi2=5.9440  , p=0.5463  , df=7
# likelihood ratio test: chi2=5.9342  , p=0.5475  , df=7
# parameter F test:         F=0.8421  , p=0.5523  , df_denom=1781, df_num=7
#
# Granger Causality
# number of lags (no zero) 8
# ssr based F test:         F=1.1210  , p=0.3456  , df_denom=1778, df_num=8
# ssr based chi2 test:   chi2=9.0541  , p=0.3378  , df=8
# likelihood ratio test: chi2=9.0313  , p=0.3397  , df=8
# parameter F test:         F=1.1210  , p=0.3456  , df_denom=1778, df_num=8
#
# Granger Causality
# number of lags (no zero) 9
# ssr based F test:         F=1.0082  , p=0.4310  , df_denom=1775, df_num=9
# ssr based chi2 test:   chi2=9.1712  , p=0.4216  , df=9
# likelihood ratio test: chi2=9.1478  , p=0.4237  , df=9
# parameter F test:         F=1.0082  , p=0.4310  , df_denom=1775, df_num=9
#
# Granger Causality
# number of lags (no zero) 10
# ssr based F test:         F=0.9397  , p=0.4953  , df_denom=1772, df_num=10
# ssr based chi2 test:   chi2=9.5079  , p=0.4847  , df=10
# likelihood ratio test: chi2=9.4828  , p=0.4870  , df=10
# parameter F test:         F=0.9397  , p=0.4953  , df_denom=1772, df_num=10
# {'CNY': ['VND', 'MRU', 'CDF', 'PKR'],
#  'EUR': ['ALL', 'CZK', 'TND', 'RON', 'RSD', 'DZD', 'HUF', 'SEK', 'ISK', 'PLN'],
#  'JPY': ['MYR', 'TWD', 'THB', 'IDR', 'AUD']}

# %%
an
# Out:
#    anchor neighbor  min_pval  best_lag (days)  significant
# 0     CNY      VND    0.0000                9         True
# 1     CNY      MRU    0.0018               10         True
# 2     CNY      CDF    0.0123                1         True
# 3     CNY      PKR    0.0201                5         True
# 9     EUR      ALL    0.0000               10         True
# 10    EUR      CZK    0.0000                3         True
# 11    EUR      TND    0.0000                8         True
# 12    EUR      RON    0.0000                1         True
# 13    EUR      RSD    0.0000                4         True
# 14    EUR      DZD    0.0000               10         True
# 15    EUR      HUF    0.0001               10         True
# 16    EUR      SEK    0.0012                1         True
# 17    EUR      ISK    0.0016                1         True
# 18    EUR      PLN    0.0285                9         True
# 19    JPY      MYR    0.0000                1         True
# 20    JPY      TWD    0.0013               10         True
# 21    JPY      THB    0.0027                8         True
# 22    JPY      IDR    0.0029                1         True
# 23    JPY      AUD    0.0212                8         True

# %%
# P-value: Lower is stronger correlation
# Best Lag: Strongest correlation (VND) best was 9 days after CNY
# The Euro is the strongest finding, PCA only looks at movement (not lags taken into account)
# # Run all on XGBoost and then discard if not useful

rdf
# Out:
#    anchor neighbor  min_pval  best_lag (days)  significant
# 0     CNY      VND    0.0000                9         True
# 1     CNY      MRU    0.0018               10         True
# 2     CNY      CDF    0.0123                1         True
# 3     CNY      PKR    0.0201                5         True
# 4     CNY      LAK    0.0513                2        False
# 5     CNY      CLP    0.1205                1        False
# 6     CNY      GNF    0.2345                1        False
# 7     CNY      TZS    0.2517                2        False
# 8     CNY      PHP    0.5106                9        False
# 9     EUR      ALL    0.0000               10         True
# 10    EUR      CZK    0.0000                3         True
# 11    EUR      TND    0.0000                8         True
# 12    EUR      RON    0.0000                1         True
# 13    EUR      RSD    0.0000                4         True
# 14    EUR      DZD    0.0000               10         True
# 15    EUR      HUF    0.0001               10         True
# 16    EUR      SEK    0.0012                1         True
# 17    EUR      ISK    0.0016                1         True
# 18    EUR      PLN    0.0285                9         True
# 19    JPY      MYR    0.0000                1         True
# 20    JPY      TWD    0.0013               10         True
# 21    JPY      THB    0.0027                8         True
# 22    JPY      IDR    0.0029                1         True
# 23    JPY      AUD    0.0212                8         True
# 24    JPY      KRW    0.0706                1        False
# 25    JPY      NZD    0.3468                8        False
# 26    JPY      PGK    0.3643                8        False

# %%
## Guess i will start some basic visualizations.

# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.imshow.html

# see if you guys like something like this. 

# test visualization, heatmap, neighbors to anchor, granger

pv = rdf.pivot(index = "anchor", columns = "neighbor", values = "min_pval")
pv = pv.fillna(1.0)

plt.figure(figsize = (12, 4 + 0.10 * len(pv.index)))
plt.imshow(pv.values, aspect = "auto", cmap="viridis")
plt.xticks(ticks = np.arange(pv.shape[1]), labels = pv.columns, rotation = 90)
plt.yticks(ticks = np.arange(pv.shape[0]), labels = pv.index)
plt.colorbar(label = "p_value")
plt.title("Granger Causality, Anchor and neighbors")
plt.tight_layout
plt.show()

# %%
# something simple to start for best_estimator_

best_model = xgb_grid.best_params_

feature_names = list(X.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 # something simple to start for best_estimator_
# ----> 3 best_model = xgb_grid.best_params_
#       5 feature_names = list(X.columns)
#
# NameError: name 'xgb_grid' is not defined

# %%
# notice above is only CNY and CAD, so

# %%
ls_0 = [i for i in ng.items() if i[0] == 'EUR'][0]
ls_1 = [ls_0[0] for i in range(len([i for i in ng.items() if i[0] == 'EUR'][0][1]))]
len(ls_0[1]), len(ls_1)

pd.DataFrame({'Anchor': ls_1, 'Neighbor': ls_0[1]})
# Out:
#   Anchor Neighbor
# 0    EUR      ALL
# 1    EUR      CZK
# 2    EUR      TND
# 3    EUR      RON
# 4    EUR      RSD
# 5    EUR      DZD
# 6    EUR      HUF
# 7    EUR      SEK
# 8    EUR      ISK
# 9    EUR      PLN

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=619db6da-a06b-4834-b7df-60521a3a0b3a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
